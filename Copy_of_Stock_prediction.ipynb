# %% [markdown]
# <a href="https://colab.research.google.com/github/vibhumkhanna/Stock-Prediction-Model-/blob/main/Copy_of_Stock_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

# For reading stock data from yahoo
from pandas_datareader.data import DataReader

# For time stamps
from datetime import datetime

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
# The tech stocks we'll use for this analysis
tech_list = ['AAPL', 'GOOG', 'MSFT', 'AMZN', 'TSLA', 'GME', 'TTM', 'RS']

# Set up End and Start times for data grab
end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)


#For loop for grabing yahoo finance data and setting as a dataframe
for stock in tech_list:   
    # Set DataFrame as the Stock Ticker
    globals()[stock] = DataReader(stock, 'yahoo', start, end)

# %%
company_list = [AAPL, GOOG, MSFT, AMZN, TSLA, GME, TTM, RS]
company_name = ["APPLE", "GOOGLE", "MICROSOFT", "AMAZON", "TESLA", "GAMESTOCK", "TATA", "RELIANCE"]

for company, com_name in zip(company_list, company_name):
    company["company_name"] = com_name
    
df = pd.concat(company_list, axis=0)
df.tail(10)
# Out:
#                   High         Low  ...   Adj Close  company_name
# Date                                ...
# 2021-05-06  175.000000  170.360001  ...  174.990005      RELIANCE
# 2021-05-07  177.820007  171.809998  ...  177.240005      RELIANCE
# 2021-05-10  181.210007  175.309998  ...  175.679993      RELIANCE
# 2021-05-11  177.529999  172.619995  ...  176.479996      RELIANCE
# 2021-05-12  176.509995  166.449997  ...  167.830002      RELIANCE
# 2021-05-13  174.380005  168.240005  ...  172.440002      RELIANCE
# 2021-05-14  173.699997  169.600006  ...  170.559998      RELIANCE
# 2021-05-17  171.250000  166.990005  ...  170.600006      RELIANCE
# 2021-05-18  171.610001  167.660004  ...  167.809998      RELIANCE
# 2021-05-19  164.710007  163.565002  ...  164.315002      RELIANCE
#
# [10 rows x 7 columns]

# %%
df.head(50)
# Out:
#                  High        Low  ...  Adj Close  company_name
# Date                              ...
# 2020-05-19  79.629997  78.252502  ...  77.761040         APPLE
# 2020-05-20  79.879997  79.129997  ...  79.273354         APPLE
# 2020-05-21  80.222504  78.967499  ...  78.682327         APPLE
# 2020-05-22  79.807503  78.837502  ...  79.188927         APPLE
# 2020-05-26  81.059998  79.125000  ...  78.652542         APPLE
# 2020-05-27  79.677498  78.272499  ...  78.995224         APPLE
# 2020-05-28  80.860001  78.907501  ...  79.029984         APPLE
# 2020-05-29  80.287498  79.117500  ...  78.953018         APPLE
# 2020-06-01  80.587502  79.302498  ...  79.923965         APPLE
# 2020-06-02  80.860001  79.732498  ...  80.293968         APPLE
# 2020-06-03  81.550003  80.574997  ...  80.735992         APPLE
# 2020-06-04  81.404999  80.195000  ...  80.040680         APPLE
# 2020-06-05  82.937500  80.807503  ...  82.320328         APPLE
# ...

# %%
AAPL.describe()
# Out:
#              High         Low        Open       Close        Volume   Adj Close
# count  253.000000  253.000000  253.000000  253.000000  2.530000e+02  253.000000
# mean   117.971779  114.922727  116.555415  116.471979  1.273142e+08  116.041609
# std     16.220509   15.808807   16.153245   15.988861  5.306514e+07   16.090842
# min     79.629997   78.252502   78.757500   78.285004  8.895864e+06   77.761040
# 25%    112.440002  108.897499  110.497498  110.440002  9.022180e+07  109.898621
# 50%    121.660004  118.809998  120.330002  120.300003  1.124244e+08  119.926292
# 75%    129.720001  126.760002  128.500000  127.900002  1.531980e+08  127.683121
# max    145.089996  141.369995  143.600006  143.160004  3.743368e+08  142.704010

# %%
GOOG.describe()
# Out:
#               High          Low  ...        Volume    Adj Close
# count   253.000000   253.000000  ...  2.530000e+02   253.000000
# mean   1789.094883  1749.878486  ...  1.640893e+06  1769.861477
# std     300.083984   297.646406  ...  5.992030e+05   298.861146
# min    1392.000000  1347.010010  ...  9.373900e+04  1359.900024
# 25%    1521.900024  1488.400024  ...  1.272100e+06  1511.339966
# 50%    1756.000000  1720.219971  ...  1.513500e+06  1739.369995
# 75%    2075.500000  2021.609985  ...  1.828400e+06  2049.090088
# max    2452.377930  2402.280029  ...  4.329100e+06  2429.889893
#
# [8 rows x 6 columns]

# %%
AMZN.describe()
# Out:
#               High          Low  ...        Volume    Adj Close
# count   253.000000   253.000000  ...  2.530000e+02   253.000000
# mean   3159.576868  3080.000038  ...  4.279826e+06  3118.862759
# std     241.277625   236.692311  ...  1.454071e+06   237.367143
# min    2413.580078  2330.000000  ...  3.927970e+05  2401.100098
# 25%    3114.000000  3019.479980  ...  3.174100e+06  3074.959961
# 50%    3198.750000  3127.300049  ...  3.998100e+06  3162.239990
# 75%    3312.620117  3228.689941  ...  5.094000e+06  3270.389893
# max    3554.000000  3486.689941  ...  8.892600e+06  3531.449951
#
# [8 rows x 6 columns]

# %%
RS.describe()
# Out:
#              High         Low        Open       Close        Volume   Adj Close
# count  253.000000  253.000000  253.000000  253.000000  2.530000e+02  253.000000
# mean   122.126403  118.985672  120.599288  120.565395  3.693124e+05  119.727317
# std     22.557762   21.939998   22.342765   22.371033  1.626990e+05   22.875554
# min     91.820000   89.379997   89.860001   89.879997  1.204700e+04   88.475342
# 25%    105.360001  102.370003  103.769997  103.489998  2.717000e+05  102.468735
# 50%    119.029999  116.129997  117.970001  117.580002  3.381000e+05  117.033562
# 75%    134.360001  130.880005  132.250000  132.250000  4.341000e+05  131.638275
# max    181.210007  175.309998  180.139999  177.240005  1.279600e+06  177.240005

# %%
TSLA.describe()
# Out:
#              High         Low        Open       Close        Volume   Adj Close
# count  253.000000  253.000000  253.000000  253.000000  2.530000e+02  253.000000
# mean   525.605075  499.203842  513.353234  513.458189  5.103300e+07  513.458189
# std    211.009183  202.773915  207.530276  207.178444  2.900933e+07  207.178444
# min    164.414001  157.000000  161.750000  161.162003  6.249166e+06  161.162003
# 25%    369.000000  334.566010  356.000000  366.279999  3.126630e+07  366.279999
# 50%    496.000000  443.500000  460.170013  475.049988  4.255200e+07  475.049988
# 75%    700.700012  667.840027  685.700012  682.219971  6.591950e+07  682.219971
# max    900.400024  871.599976  891.380005  883.090027  2.221262e+08  883.090027

# %%
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 253 entries, 2020-05-19 to 2021-05-19
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   High          253 non-null    float64
#  1   Low           253 non-null    float64
#  2   Open          253 non-null    float64
#  3   Close         253 non-null    float64
#  4   Volume        253 non-null    float64
#  5   Adj Close     253 non-null    float64
#  6   company_name  253 non-null    object
# dtypes: float64(6), object(1)
# memory usage: 15.8+ KB

# %%
GME.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 253 entries, 2020-05-19 to 2021-05-19
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   High          253 non-null    float64
#  1   Low           253 non-null    float64
#  2   Open          253 non-null    float64
#  3   Close         253 non-null    float64
#  4   Volume        253 non-null    int64
#  5   Adj Close     253 non-null    float64
#  6   company_name  253 non-null    object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 15.8+ KB

# %%
GME.describe()
# Out:
#              High         Low        Open       Close        Volume   Adj Close
# count  253.000000  253.000000  253.000000  253.000000  2.530000e+02  253.000000
# mean    63.218459   50.791502   57.183518   56.044743  1.708007e+07   56.044743
# std     88.574855   67.750547   78.895403   75.750220  2.848941e+07   75.750220
# min      4.050000    3.770000    3.900000    3.850000  6.694380e+05    3.850000
# 25%      5.080000    4.650000    4.880000    4.950000  3.812800e+06    4.950000
# 50%     14.120000   12.670000   13.340000   13.490000  7.386300e+06   13.490000
# 75%    133.990005   85.250000  112.010002  101.739998  1.490800e+07  101.739998
# max    483.000000  262.269989  379.709991  347.510010  1.971579e+08  347.510010

# %%
# Looking at the closing price of the stocks that we have selected, and plotting them


plt.figure(figsize=(15, 6))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 4, i)
    company['Adj Close'].plot()
    plt.ylabel('Adj Close')
    plt.xlabel(None)
    plt.title(f"Closing Price of {tech_list[i - 1]}")
    
plt.tight_layout()

# %%
# looking at the total volume of stock being traded each day, we plot them. Sales volume is an essential indicator of business health. 
#It allows you to track the performance of marketing campaigns, evaluate the efforts of sales representatives, and choose the best places for physical stores.

plt.figure(figsize=(15, 7))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(3, 3, i)
    company['Volume'].plot()
    plt.ylabel('Volume')
    plt.xlabel(None)
    plt.title(f"Sales Volume for {tech_list[i - 1]}")
    
plt.tight_layout()

# %%
#MA is the moving avg for each stock

ma_day = [10, 20, 50]

for ma in ma_day:
    for company in company_list:
        column_name = f"MA for {ma} days"
        company[column_name] = company['Adj Close'].rolling(ma).mean()

# %%
print(GOOG.columns)
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close', 'company_name',
#        'MA for 10 days', 'MA for 20 days', 'MA for 50 days'],
#       dtype='object')

# %%
df.groupby("company_name").hist(figsize=(12, 12));

# %%
fig, axes = plt.subplots(nrows=2, ncols=4)
fig.set_figheight(8)
fig.set_figwidth(15)

AAPL[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,0])
axes[0,0].set_title('APPLE')

GOOG[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,1])
axes[0,1].set_title('GOOGLE')

MSFT[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,0])
axes[1,0].set_title('MICROSOFT')

AMZN[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,1])
axes[1,1].set_title('AMAZON')

TSLA[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,2])
axes[0,2].set_title('TESLA')

GME[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,3])
axes[0,3].set_title('GAMESTOCK')

TTM[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,2])
axes[1,2].set_title('TATA')

RS[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,3])
axes[1,3].set_title('RELIANCE')

fig.tight_layout()

# %%
# We'll use pct_change to find the percent change for each day
for company in company_list:
    company['Daily Return'] = company['Adj Close'].pct_change()

# Then we'll plot the daily return percentage
fig, axes = plt.subplots(nrows=2, ncols=4)
fig.set_figheight(8)
fig.set_figwidth(15)

AAPL['Daily Return'].plot(ax=axes[0,0], legend=True, linestyle='--', marker='o')
axes[0,0].set_title('APPLE')

GOOG['Daily Return'].plot(ax=axes[0,1], legend=True, linestyle='--', marker='o')
axes[0,1].set_title('GOOGLE')

MSFT['Daily Return'].plot(ax=axes[1,0], legend=True, linestyle='--', marker='o')
axes[1,0].set_title('MICROSOFT')

AMZN['Daily Return'].plot(ax=axes[1,1], legend=True, linestyle='--', marker='o')
axes[1,1].set_title('AMAZON')

TSLA['Daily Return'].plot(ax=axes[0,2], legend=True, linestyle='--', marker='o')
axes[0,2].set_title('TESLA')

GME['Daily Return'].plot(ax=axes[0,3], legend=True, linestyle='--', marker='o')
axes[0,3].set_title('GAMESTOCK')

TTM['Daily Return'].plot(ax=axes[1,2], legend=True, linestyle='--', marker='o')
axes[1,2].set_title('TATA')

RS['Daily Return'].plot(ax=axes[1,3], legend=True, linestyle='--', marker='o')
axes[1,3].set_title('RELIANCE')

fig.tight_layout()

# %%
# Note the use of dropna() here, otherwise the NaN values can't be read by seaborn
plt.figure(figsize=(12, 7))

for i, company in enumerate(company_list, 1):
    plt.subplot(3, 3, i)
    sns.distplot(company['Daily Return'].dropna(), bins=100, color='purple')
    plt.ylabel('Daily Return')
    plt.title(f'{company_name[i - 1]}')
# Could have also done:
#AAPL['Daily Return'].hist()
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Grab all the closing prices for the tech stock list into one DataFrame
closing_df = DataReader(tech_list, 'yahoo', start, end)['Adj Close']
closing_df.head(10)
# Out:
# Symbols          AAPL         GOOG        MSFT  ...   GME   TTM         RS
# Date                                            ...
# 2020-05-19  77.761040  1373.484985  181.782730  ...  4.44  5.32  89.421722
# 2020-05-20  79.273354  1406.719971  184.304169  ...  4.43  5.51  89.304344
# 2020-05-21  78.682327  1402.800049  182.090454  ...  4.44  5.57  89.284782
# 2020-05-22  79.188927  1410.420044  182.169861  ...  4.18  5.46  89.460846
# 2020-05-26  78.652542  1417.020020  180.244049  ...  4.42  5.61  92.082260
# 2020-05-27  78.995224  1417.839966  180.482285  ...  4.69  5.81  96.591499
# 2020-05-28  79.029984  1416.729980  180.075272  ...  4.33  5.75  96.153458
# 2020-05-29  78.953018  1428.920044  181.911774  ...  4.06  5.71  95.484085
# 2020-06-01  79.923965  1431.819946  181.494843  ...  4.13  6.06  96.429077
# 2020-06-02  80.293968  1439.219971  183.559647  ...  4.18  6.61  97.000008
#
# [10 rows x 8 columns]

# %%
# Make a new tech returns DataFrame
tech_rets = closing_df.pct_change()
tech_rets.head(10)
# Out:
# Symbols         AAPL      GOOG      MSFT  ...       GME       TTM        RS
# Date                                      ...
# 2020-05-19       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2020-05-20  0.019448  0.024198  0.013871  ... -0.002252  0.035714 -0.001313
# 2020-05-21 -0.007456 -0.002787 -0.012011  ...  0.002257  0.010889 -0.000219
# 2020-05-22  0.006439  0.005432  0.000436  ... -0.058559 -0.019749  0.001972
# 2020-05-26 -0.006773  0.004679 -0.010572  ...  0.057416  0.027473  0.029302
# 2020-05-27  0.004357  0.000579  0.001322  ...  0.061086  0.035651  0.048970
# 2020-05-28  0.000440 -0.000783 -0.002255  ... -0.076759 -0.010327 -0.004535
# 2020-05-29 -0.000974  0.008604  0.010199  ... -0.062356 -0.006957 -0.006962
# 2020-06-01  0.012298  0.002029 -0.002292  ...  0.017241  0.061296  0.009897
# 2020-06-02  0.004629  0.005168  0.011377  ...  0.012106  0.090759  0.005921
#
# [10 rows x 8 columns]

# %%
sns.jointplot('RS', 'RS', tech_rets, kind='scatter', color='seagreen')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot('AMZN', 'TSLA', tech_rets, kind='scatter', color='red')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot('GME', 'TTM', tech_rets, kind='scatter', color='red')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# We can simply call pairplot on our DataFrame for an automatic visual analysis of all the comparisons

sns.pairplot(tech_rets, kind='reg')

# %%
# Set up our figure by naming it returns_fig, call PairPLot on the DataFrame
return_fig = sns.PairGrid(tech_rets.dropna())

# Using map_upper we can specify what the upper triangle will look like.
return_fig.map_upper(plt.scatter, color='purple')

# We can also define the lower triangle in the figure, including the plot type (kde) or the color map (BluePurple)
return_fig.map_lower(sns.kdeplot, cmap='cool_d')

# Finally we'll define the diagonal as a series of histogram plots of the daily return
return_fig.map_diag(plt.hist, bins=30)

# %%
# Set up our figure by naming it returns_fig, call PairPLot on the DataFrame
returns_fig = sns.PairGrid(closing_df)

# Using map_upper we can specify what the upper triangle will look like.
returns_fig.map_upper(plt.scatter,color='purple')

# We can also define the lower triangle in the figure, inclufing the plot type (kde) or the color map (BluePurple)
returns_fig.map_lower(sns.kdeplot,cmap='cool_d')

# Finally we'll define the diagonal as a series of histogram plots of the daily return
returns_fig.map_diag(plt.hist,bins=30)

# %%
# Let's go ahead and use seaborn for a quick correlation plot for the daily returns
sns.heatmap(tech_rets.corr(), annot=True, cmap='Blues')

# %%
sns.heatmap(closing_df.corr(), annot=True, cmap='Blues')

# %%
# Let's start by defining a new DataFrame as a cleaned version of the orignal tech_rets DataFrame
rets = tech_rets.dropna()

area = np.pi * 20

plt.figure(figsize=(10, 7))
plt.scatter(rets.mean(), rets.std(), s=area)
plt.xlabel('Expected return')
plt.ylabel('Risk')

for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(label, xy=(x, y), xytext=(50, 50), textcoords='offset points', ha='right', va='bottom', arrowprops=dict(arrowstyle='-', color='blue', connectionstyle='arc3,rad=-0.3'))

# %%
# Get the stock quote
df = DataReader('AAPL', data_source='yahoo', start='2010-01-01', end=datetime.now())
# Show the data
df
# Out:
#                   High         Low  ...       Volume   Adj Close
# Date                                ...
# 2010-01-04    7.660714    7.585000  ...  493729600.0    6.572422
# 2010-01-05    7.699643    7.616071  ...  601904800.0    6.583784
# 2010-01-06    7.686786    7.526786  ...  552160000.0    6.479061
# 2010-01-07    7.571429    7.466071  ...  477131200.0    6.467082
# 2010-01-08    7.571429    7.466429  ...  447610800.0    6.510078
# ...                ...         ...  ...          ...         ...
# 2021-05-13  126.150002  124.260002  ...  105861300.0  124.970001
# 2021-05-14  127.889999  125.849998  ...   81806500.0  127.449997
# 2021-05-17  126.930000  125.169998  ...   74244600.0  126.269997
# 2021-05-18  126.989998  124.779999  ...   63130600.0  124.849998
# 2021-05-19  124.070000  122.879997  ...   10642673.0  123.879997
#
# [2864 rows x 6 columns]

# %%
plt.figure(figsize=(16,6))
plt.title('Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
# Get the stock quote
df2 = DataReader('GOOG', data_source='yahoo', start='2010-01-01', end=datetime.now())
# Show the data
df2
# Out:
#                    High          Low  ...      Volume    Adj Close
# Date                                  ...
# 2010-01-04   313.579620   310.954468  ...   3927065.0   312.204773
# 2010-01-05   312.747742   309.609497  ...   6031925.0   310.829926
# 2010-01-06   311.761444   302.047852  ...   7987226.0   302.994293
# 2010-01-07   303.861053   295.218445  ...  12876685.0   295.940735
# 2010-01-08   300.498657   293.455048  ...   9484016.0   299.885956
# ...                 ...          ...  ...         ...          ...
# 2021-05-13  2276.601074  2242.719971  ...   1333500.0  2261.969971
# 2021-05-14  2321.139893  2283.320068  ...   1330100.0  2316.159912
# 2021-05-17  2323.340088  2295.000000  ...    992100.0  2321.409912
# 2021-05-18  2343.149902  2303.159912  ...    864400.0  2303.429932
# 2021-05-19  2278.600098  2263.520020  ...    111762.0  2273.020020
#
# [2864 rows x 6 columns]

# %%
plt.figure(figsize=(16,6))
plt.title('Close Price History')
plt.plot(df2['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
# Get the stock quote
df3 = DataReader('AMZN', data_source='yahoo', start='2010-01-01', end=datetime.now())
plt.figure(figsize=(16,6))
plt.title('Close Price History')
plt.plot(df3['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
# Get the stock quote
df4 = DataReader('MSFT', data_source='yahoo', start='2010-01-01', end=datetime.now())
plt.figure(figsize=(16,6))
plt.title('Close Price History')
plt.plot(df4['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
# Get the stock quote
df5 = DataReader('TSLA', data_source='yahoo', start='2010-01-01', end=datetime.now())
plt.figure(figsize=(16,6))
plt.title('Close Price History')
plt.plot(df5['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
# Get the stock quote
df6 = DataReader('GME', data_source='yahoo', start='2010-01-01', end=datetime.now())
plt.figure(figsize=(16,6))
plt.title('Close Price History')
plt.plot(df6['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
# Get the stock quote
df7 = DataReader('TTM', data_source='yahoo', start='2010-01-01', end=datetime.now())
plt.figure(figsize=(16,6))
plt.title('Close Price History')
plt.plot(df7['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
# Get the stock quote
df8 = DataReader('RS', data_source='yahoo', start='2010-01-01', end=datetime.now())
plt.figure(figsize=(16,6))
plt.title('Close Price History')
plt.plot(df8['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
# Create a new dataframe with only the Close column 
data = df.filter(['Close'])
# Convert the dataframe to a numpy array
dataset = data.values
# Get the number of rows to train the model on
training_data_len = int(np.ceil( len(dataset) * .95 ))

print(training_data_len)

# Create a new dataframe with only the 'Close column 
data2 = df2.filter(['Close'])
# Convert the dataframe to a numpy array
dataset2 = data2.values
# Get the number of rows to train the model on
training_data_len2 = int(np.ceil( len(dataset) * .95 ))

# Create a new dataframe with only the 'Close column 
data3 = df3.filter(['Close'])
# Convert the dataframe to a numpy array
dataset3 = data3.values
# Get the number of rows to train the model on
training_data_len3 = int(np.ceil( len(dataset) * .95 ))

# Create a new dataframe with only the 'Close column 
data4 = df4.filter(['Close'])
# Convert the dataframe to a numpy array
dataset4 = data4.values
# Get the number of rows to train the model on
training_data_len4 = int(np.ceil( len(dataset) * .95 ))

# Create a new dataframe with only the 'Close column 
data5 = df5.filter(['Close'])
# Convert the dataframe to a numpy array
dataset5 = data5.values
# Get the number of rows to train the model on
training_data_len5 = int(np.ceil( len(dataset) * .95 ))

# Create a new dataframe with only the 'Close column 
data6 = df6.filter(['Close'])
# Convert the dataframe to a numpy array
dataset6 = data6.values
# Get the number of rows to train the model on
training_data_len6 = int(np.ceil( len(dataset) * .95 ))

# Create a new dataframe with only the 'Close column 
data7 = df7.filter(['Close'])
# Convert the dataframe to a numpy array
dataset7 = data7.values
# Get the number of rows to train the model on
training_data_len7 = int(np.ceil( len(dataset) * .95 ))

# Create a new dataframe with only the 'Close column 
data8 = df8.filter(['Close'])
# Convert the dataframe to a numpy array
dataset8 = data8.values
# Get the number of rows to train the model on
training_data_len8 = int(np.ceil( len(dataset) * .95 ))
# Out:
# 2721

# %%
# Scale the data
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

scaled_data
# Out:
# array([[0.00575406],
#        [0.00585102],
#        [0.00495751],
#        ...,
#        [0.8760831 ],
#        [0.865665  ],
#        [0.85854839]])

# %%
scaler2 = MinMaxScaler(feature_range=(0,1))
scaled_data2 = scaler2.fit_transform(dataset2)

scaled_data2
# Out:
# array([[0.04292732],
#        [0.04230597],
#        [0.03876471],
#        ...,
#        [0.95097325],
#        [0.94284732],
#        [0.92910378]])

# %%
scaler3 = MinMaxScaler(feature_range=(0,1))
scaled_data3 = scaler3.fit_transform(dataset3)

scaled_data3
# Out:
# array([[0.0073886 ],
#        [0.0076194 ],
#        [0.00690655],
#        ...,
#        [0.92372998],
#        [0.91259599],
#        [0.90678207]])

# %%
scaler4 = MinMaxScaler(feature_range=(0,1))
scaled_data4 = scaler4.fit_transform(dataset4)

scaled_data4
# Out:
# array([[0.03322732],
#        [0.03326916],
#        [0.03247406],
#        ...,
#        [0.92973716],
#        [0.92094912],
#        [0.91023604]])

# %%
scaler5 = MinMaxScaler(feature_range=(0,1))
scaled_data5 = scaler5.fit_transform(dataset5)

scaled_data5
# Out:
# array([[0.00183878],
#        [0.00182514],
#        [0.00140011],
#        ...,
#        [0.65194959],
#        [0.65313147],
#        [0.62634524]])

# %%
scaler6 = MinMaxScaler(feature_range=(0,1))
scaled_data6 = scaler6.fit_transform(dataset6)

scaled_data6
# Out:
# array([[0.05830988],
#        [0.0601085 ],
#        [0.061588  ],
#        ...,
#        [0.51579589],
#        [0.51599894],
#        [0.49630124]])

# %%
scaler7 = MinMaxScaler(feature_range=(0,1))
scaled_data7 = scaler7.fit_transform(dataset7)

scaled_data7
# Out:
# array([[0.29436591],
#        [0.29056763],
#        [0.29352183],
#        ...,
#        [0.37602868],
#        [0.3762397 ],
#        [0.35218401]])

# %%
scaler8 = MinMaxScaler(feature_range=(0,1))
scaled_data8 = scaler8.fit_transform(dataset8)

scaled_data8
# Out:
# array([[0.09352615],
#        [0.09104681],
#        [0.10179062],
#        ...,
#        [0.95426998],
#        [0.93505504],
#        [0.90192834]])

# %%
# Create the training data set 
# Create the scaled training data set
train_data = scaled_data[0:int(training_data_len), :]
# Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    if i<= 61:
        print(x_train)
        print(y_train)
        print()
        
# Convert the x_train and y_train to numpy arrays 
x_train, y_train = np.array(x_train), np.array(y_train)

# Reshape the data
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# x_train.shape
# Out:
# [array([5.75406373e-03, 5.85101519e-03, 4.95751056e-03, 4.85531498e-03,
#        5.22215135e-03, 4.73217092e-03, 4.10592389e-03, 4.87365715e-03,
#        4.55398986e-03, 3.63690244e-03, 6.02394863e-03, 5.15665060e-03,
#        4.19763123e-03, 1.49353806e-03, 2.88751135e-03, 3.63952275e-03,
#        4.14785234e-03, 1.89705527e-03, 2.61681132e-06, 7.02222017e-04,
#        9.98310019e-04, 1.88133341e-03, 0.00000000e+00, 8.93497630e-04,
#        5.42386622e-04, 1.08478024e-03, 8.04410598e-04, 1.73459956e-03,
#        2.18266553e-03, 2.97398157e-03, 2.75126224e-03, 2.85082702e-03,
#        2.52067499e-03, 2.19314327e-03, 1.31274019e-03, 2.25603420e-03,
#        2.60714521e-03, 3.29364886e-03, 4.43870323e-03, 4.40201889e-03,
#        4.52778326e-03, 4.88937901e-03, 7.04846874e-03, 7.08253277e-03,
#        8.11491031e-03, 8.59179269e-03, 8.76472614e-03, 9.05296021e-03,
#        8.32977221e-03, 8.48960411e-03, 8.40313739e-03, 8.54201030e-03,
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# Build the LSTM model
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape= (x_train.shape[1], 1)))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, batch_size=1, epochs=1)
# Out:
# 2661/2661 [==============================] - 79s 29ms/step - loss: 0.0014

# %%
# Create the testing data set
# Create a new array containing scaled values from index 1543 to 2002 
test_data = scaled_data[training_data_len - 60: , :]
# Create the data sets x_test and y_test
x_test = []
y_test = dataset[training_data_len:, :]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
    
# Convert the data to a numpy array
x_test = np.array(x_test)

# Reshape the data
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))

# Get the models predicted price values 
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

# Get the root mean squared error (RMSE)
rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
rmse
# Out:
# 3.745682555444281

# %%
# Plot the data
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions
# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Apple')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
valid
# Out:
#                  Close  Predictions
# Date
# 2020-10-23  115.040001   116.179985
# 2020-10-26  115.050003   115.542671
# 2020-10-27  116.599998   115.036194
# 2020-10-28  111.199997   114.968826
# 2020-10-29  115.320000   114.079857
# ...                ...          ...
# 2021-05-13  124.970001   125.487022
# 2021-05-14  127.449997   124.658081
# 2021-05-17  126.269997   124.619957
# 2021-05-18  124.849998   124.666115
# 2021-05-19  123.879997   124.479073
#
# [143 rows x 2 columns]

# %%
# Create the training data set 
# Create the scaled training data set
train_data2 = scaled_data2[0:int(training_data_len2), :]
# Split the data into x_train and y_train data sets
x_train2 = []
y_train2 = []

for i in range(60, len(train_data2)):
    x_train2.append(train_data2[i-60:i, 0])
    y_train2.append(train_data2[i, 0])
    if i<= 61:
        print(x_train2)
        print(y_train2)
        print()
        
# Convert the x_train and y_train to numpy arrays 
x_train2, y_train2 = np.array(x_train2), np.array(y_train2)

# Reshape the data
x_train2 = np.reshape(x_train2, (x_train2.shape[0], x_train2.shape[1], 1))
# x_train.shape
# Out:
# [array([0.04292732, 0.04230597, 0.03876471, 0.03557691, 0.03735992,
#        0.03715505, 0.03476195, 0.03399876, 0.03462012, 0.03240261,
#        0.03411808, 0.03249492, 0.03307349, 0.02565103, 0.02339751,
#        0.02394232, 0.02387028, 0.02211202, 0.02113272, 0.02182611,
#        0.02139837, 0.02358211, 0.02042132, 0.02143665, 0.02192743,
#        0.02259606, 0.02214805, 0.02258705, 0.02184863, 0.02369017,
#        0.02299453, 0.02412242, 0.0235686 , 0.02402787, 0.02228763,
#        0.02147717, 0.02034253, 0.02042583, 0.02175183, 0.02363614,
#        0.02459518, 0.02668212, 0.02884784, 0.02845838, 0.02794283,
#        0.0316034 , 0.03265925, 0.03229905, 0.02861597, 0.02907073,
#        0.02915177, 0.02934087, 0.02790006, 0.02733724, 0.02542365,
#        0.02729897, 0.02854843, 0.02850566, 0.02845162, 0.02941066])]
# [0.029502974360690243]
#
# [array([0.04292732, 0.04230597, 0.03876471, 0.03557691, 0.03735992,
#        0.03715505, 0.03476195, 0.03399876, 0.03462012, 0.03240261,
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# Build the LSTM model
model2 = Sequential()
model2.add(LSTM(128, return_sequences=True, input_shape= (x_train2.shape[1], 1)))
model2.add(LSTM(64, return_sequences=False))
model2.add(Dense(25))
model2.add(Dense(1))

# Compile the model
model2.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model2.fit(x_train2, y_train2, batch_size=1, epochs=1)
# Out:
# 2661/2661 [==============================] - 78s 29ms/step - loss: 0.0019

# %%
# Create the testing data set
# Create a new array containing scaled values from index 1543 to 2002 
test_data2 = scaled_data2[training_data_len2 - 60: , :]
# Create the data sets x_test and y_test
x_test2 = []
y_test2 = dataset2[training_data_len2:, :]
for i in range(60, len(test_data2)):
    x_test2.append(test_data2[i-60:i, 0])
    
# Convert the data to a numpy array
x_test2 = np.array(x_test2)

# Reshape the data
x_test2 = np.reshape(x_test2, (x_test2.shape[0], x_test2.shape[1], 1 ))

# Get the models predicted price values 
predictions2 = model2.predict(x_test2)
predictions2 = scaler2.inverse_transform(predictions2)

# Get the root mean squared error (RMSE)
rmse2 = np.sqrt(np.mean(((predictions2 - y_test2) ** 2)))
rmse2
# Out:
# 61.07245289451386

# %%
# Plot the data
train2 = data2[:training_data_len2]
valid2 = data2[training_data_len2:]
valid2['Predictions'] = predictions2
# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Google')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train2['Close'])
plt.plot(valid2[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
valid2
# Out:
#                   Close  Predictions
# Date
# 2020-10-23  1641.000000  1632.526123
# 2020-10-26  1590.449951  1650.113770
# 2020-10-27  1604.260010  1656.256958
# 2020-10-28  1516.619995  1659.812988
# 2020-10-29  1567.239990  1644.500610
# ...                 ...          ...
# 2021-05-13  2261.969971  2367.600830
# 2021-05-14  2316.159912  2345.899170
# 2021-05-17  2321.409912  2342.127930
# 2021-05-18  2303.429932  2346.337158
# 2021-05-19  2273.020020  2349.032959
#
# [143 rows x 2 columns]

# %%
# Create the training data set 
# Create the scaled training data set
train_data3 = scaled_data3[0:int(training_data_len3), :]
# Split the data into x_train and y_train data sets
x_train3 = []
y_train3 = []

for i in range(60, len(train_data3)):
    x_train3.append(train_data3[i-60:i, 0])
    y_train3.append(train_data3[i, 0])
    if i<= 61:
        print(x_train3)
        print(y_train3)
        print()
        
# Convert the x_train and y_train to numpy arrays 
x_train3, y_train3 = np.array(x_train3), np.array(y_train3)

# Reshape the data
x_train3 = np.reshape(x_train3, (x_train3.shape[0], x_train3.shape[1], 1))
# x_train.shape
# Out:
# [array([0.0073886 , 0.0076194 , 0.00690655, 0.0062492 , 0.00727758,
#        0.00633976, 0.00547499, 0.00598918, 0.00547499, 0.00541363,
#        0.00555095, 0.0050163 , 0.00526171, 0.00374543, 0.00341821,
#        0.00317573, 0.00413107, 0.00508934, 0.00490821, 0.00299751,
#        0.0027784 , 0.00306471, 0.0021415 , 0.00256512, 0.00240151,
#        0.0027521 , 0.00255636, 0.00335394, 0.00322831, 0.00260602,
#        0.00224959, 0.00276671, 0.0026031 , 0.00274626, 0.0025213 ,
#        0.00324584, 0.00280177, 0.0028602 , 0.00465403, 0.00494326,
#        0.00504844, 0.00581973, 0.00593075, 0.00628133, 0.00590446,
#        0.00639819, 0.00729511, 0.00678092, 0.00657933, 0.00677215,
#        0.00664068, 0.00705554, 0.00635145, 0.00638651, 0.006033  ,
#        0.00567657, 0.00763109, 0.0077275 , 0.00774503, 0.00817158])]
# [0.00793493241121418]
#
# [array([0.0073886 , 0.0076194 , 0.00690655, 0.0062492 , 0.00727758,
#        0.00633976, 0.00547499, 0.00598918, 0.00547499, 0.00541363,
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# Build the LSTM model
model3 = Sequential()
model3.add(LSTM(128, return_sequences=True, input_shape= (x_train3.shape[1], 1)))
model3.add(LSTM(64, return_sequences=False))
model3.add(Dense(25))
model3.add(Dense(1))

# Compile the model
model3.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model3.fit(x_train3, y_train3, batch_size=1, epochs=1)
# Out:
# 2661/2661 [==============================] - 79s 29ms/step - loss: 0.0021

# %%
# Create the testing data set
# Create a new array containing scaled values from index 1543 to 2002 
test_data3 = scaled_data3[training_data_len3 - 60: , :]
# Create the data sets x_test and y_test
x_test3 = []
y_test3 = dataset3[training_data_len3:, :]
for i in range(60, len(test_data3)):
    x_test3.append(test_data3[i-60:i, 0])
    
# Convert the data to a numpy array
x_test3 = np.array(x_test3)

# Reshape the data
x_test3 = np.reshape(x_test3, (x_test3.shape[0], x_test3.shape[1], 1 ))

# Get the models predicted price values 
predictions3 = model3.predict(x_test3)
predictions3 = scaler3.inverse_transform(predictions3)

# Get the root mean squared error (RMSE)
rmse3 = np.sqrt(np.mean(((predictions3 - y_test3) ** 2)))
rmse3
# Out:
# 91.26540008905857

# %%
# Plot the data
train3 = data3[:training_data_len3]
valid3 = data3[training_data_len3:]
valid3['Predictions'] = predictions3
# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Microsoft')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train3['Close'])
plt.plot(valid3[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
valid3
# Out:
#                   Close  Predictions
# Date
# 2020-10-23  3204.399902  3168.767822
# 2020-10-26  3207.040039  3154.762207
# 2020-10-27  3286.330078  3148.602295
# 2020-10-28  3162.780029  3160.664307
# 2020-10-29  3211.010010  3156.777100
# ...                 ...          ...
# 2021-05-13  3161.469971  3178.753662
# 2021-05-14  3222.899902  3154.832520
# 2021-05-17  3270.389893  3147.951172
# 2021-05-18  3232.280029  3157.460449
# 2021-05-19  3212.379883  3165.505859
#
# [143 rows x 2 columns]

# %%
# Create the training data set 
# Create the scaled training data set
train_data4 = scaled_data4[0:int(training_data_len4), :]
# Split the data into x_train and y_train data sets
x_train4 = []
y_train4 = []

for i in range(60, len(train_data4)):
    x_train4.append(train_data4[i-60:i, 0])
    y_train4.append(train_data4[i, 0])
    if i<= 61:
        print(x_train4)
        print(y_train4)
        print()
        
# Convert the x_train and y_train to numpy arrays 
x_train4, y_train4 = np.array(x_train4), np.array(y_train4)

# Reshape the data
x_train4 = np.reshape(x_train4, (x_train4.shape[0], x_train4.shape[1], 1))
# x_train.shape
# Out:
# [array([0.03322732, 0.03326916, 0.03247406, 0.03113492, 0.03201372,
#        0.03038165, 0.02954469, 0.03071644, 0.03326916, 0.03285069,
#        0.03385504, 0.03172079, 0.02929361, 0.02489956, 0.02640609,
#        0.02715936, 0.02787077, 0.02573652, 0.02163542, 0.02259792,
#        0.02280716, 0.02351858, 0.02021259, 0.02096585, 0.01971041,
#        0.020924  , 0.02084031, 0.02138433, 0.02058922, 0.02234684,
#        0.02335119, 0.02494141, 0.02410445, 0.02393706, 0.02226314,
#        0.02351858, 0.02339304, 0.02368597, 0.02515065, 0.02280716,
#        0.02280716, 0.02351858, 0.02335119, 0.02351858, 0.02422999,
#        0.02494141, 0.02582022, 0.02619685, 0.02628055, 0.02661534,
#        0.02770338, 0.02761969, 0.02753599, 0.02757784, 0.02874958,
#        0.02778707, 0.02929361, 0.02782892, 0.02753599, 0.02828925])]
# [0.026280551810260705]
#
# [array([0.03322732, 0.03326916, 0.03247406, 0.03113492, 0.03201372,
#        0.03038165, 0.02954469, 0.03071644, 0.03326916, 0.03285069,
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# Build the LSTM model
model4 = Sequential()
model4.add(LSTM(128, return_sequences=True, input_shape= (x_train4.shape[1], 1)))
model4.add(LSTM(64, return_sequences=False))
model4.add(Dense(25))
model4.add(Dense(1))

# Compile the model
model4.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model4.fit(x_train4, y_train4, batch_size=1, epochs=2)
# Out:
# Epoch 1/2
# 2661/2661 [==============================] - 79s 29ms/step - loss: 0.0018
# Epoch 2/2
# 2661/2661 [==============================] - 77s 29ms/step - loss: 5.1805e-04

# %%
# Create the testing data set
# Create a new array containing scaled values from index 1543 to 2002 
test_data4 = scaled_data4[training_data_len4 - 60: , :]
# Create the data sets x_test and y_test
x_test4 = []
y_test4 = dataset4[training_data_len4:, :]
for i in range(60, len(test_data4)):
    x_test4.append(test_data4[i-60:i, 0])
    
# Convert the data to a numpy array
x_test4 = np.array(x_test4)

# Reshape the data
x_test4 = np.reshape(x_test4, (x_test4.shape[0], x_test4.shape[1], 1 ))

# Get the models predicted price values 
predictions4 = model4.predict(x_test4)
predictions4 = scaler4.inverse_transform(predictions4)

# Get the root mean squared error (RMSE)
rmse4 = np.sqrt(np.mean(((predictions4 - y_test4) ** 2)))
rmse4
# Out:
# 4.273935888446044

# %%
# Plot the data
train4 = data4[:training_data_len4]
valid4 = data4[training_data_len4:]
valid4['Predictions'] = predictions4
# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Amazon')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train4['Close'])
plt.plot(valid4[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
valid4
# Out:
#                  Close  Predictions
# Date
# 2020-10-23  216.229996   215.603500
# 2020-10-26  210.080002   216.156479
# 2020-10-27  213.250000   214.846634
# 2020-10-28  202.679993   214.487183
# 2020-10-29  204.720001   211.084213
# ...                ...          ...
# 2021-05-13  243.029999   245.064667
# 2021-05-14  248.149994   243.540253
# 2021-05-17  245.179993   244.672668
# 2021-05-18  243.080002   245.262924
# 2021-05-19  240.520004   244.872665
#
# [143 rows x 2 columns]

# %%
# Create the training data set 
# Create the scaled training data set
train_data5 = scaled_data5[0:int(training_data_len5), :]
# Split the data into x_train and y_train data sets
x_train5 = []
y_train5 = []

for i in range(60, len(train_data5)):
    x_train5.append(train_data5[i-60:i, 0])
    y_train5.append(train_data5[i, 0])
    if i<= 61:
        print(x_train5)
        print(y_train5)
        print()
        
# Convert the x_train and y_train to numpy arrays 
x_train5, y_train5 = np.array(x_train5), np.array(y_train5)

# Reshape the data
x_train5 = np.reshape(x_train5, (x_train5.shape[0], x_train5.shape[1], 1))
# x_train.shape
# Out:
# [array([1.83878234e-03, 1.82514479e-03, 1.40011146e-03, 7.72788526e-04,
#        7.04599183e-05, 0.00000000e+00, 3.77302748e-04, 3.63665205e-04,
#        2.84113500e-04, 5.31860399e-04, 9.18254662e-04, 9.29619191e-04,
#        1.10008713e-03, 1.38874666e-03, 1.02280844e-03, 1.00462541e-03,
#        1.18191185e-03, 1.24782628e-03, 1.17054759e-03, 1.07963136e-03,
#        1.11827070e-03, 1.03417324e-03, 9.40983720e-04, 1.16372882e-03,
#        1.39783817e-03, 1.24100751e-03, 1.05690230e-03, 8.61432016e-04,
#        8.63705030e-04, 7.34149181e-04, 4.77310496e-04, 4.09123321e-04,
#        5.72772758e-04, 6.77326535e-04, 7.61423997e-04, 6.75053521e-04,
#        6.79599278e-04, 7.50059468e-04, 9.84169094e-04, 7.72788526e-04,
#        9.31892205e-04, 8.97798618e-04, 8.86434089e-04, 9.25073434e-04,
#        8.36429944e-04, 1.05690230e-03, 1.19554939e-03, 1.19327665e-03,
#        1.07735807e-03, 1.15918279e-03, 1.11599796e-03, 9.93260609e-04,
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# Build the LSTM model
model5 = Sequential()
model5.add(LSTM(128, return_sequences=True, input_shape= (x_train5.shape[1], 1)))
model5.add(LSTM(64, return_sequences=False))
model5.add(Dense(25))
model5.add(Dense(1))

# Compile the model
model5.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model5.fit(x_train5, y_train5, batch_size=1, epochs=2)
# Out:
# Epoch 1/2
# 2661/2661 [==============================] - 80s 29ms/step - loss: 0.0037
# Epoch 2/2
# 2661/2661 [==============================] - 78s 29ms/step - loss: 0.0014

# %%
# Create the testing data set
# Create a new array containing scaled values from index 1543 to 2002 
test_data5 = scaled_data5[training_data_len5 - 60: , :]
# Create the data sets x_test and y_test
x_test5 = []
y_test5 = dataset5[training_data_len5:, :]
for i in range(60, len(test_data5)):
    x_test5.append(test_data5[i-60:i, 0])
    
# Convert the data to a numpy array
x_test5 = np.array(x_test5)

# Reshape the data
x_test5 = np.reshape(x_test5, (x_test5.shape[0], x_test5.shape[1], 1 ))

# Get the models predicted price values 
predictions5 = model5.predict(x_test5)
predictions5 = scaler5.inverse_transform(predictions5)

# Get the root mean squared error (RMSE)
rmse5 = np.sqrt(np.mean(((predictions5 - y_test5) ** 2)))
rmse5
# Out:
# 37.85711344034412

# %%
# Plot the data
train5 = data5[:training_data_len5]
valid5 = data5[training_data_len5:]
valid5['Predictions'] = predictions5
# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Tesla')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train5['Close'])
plt.plot(valid5[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
valid5
# Out:
#                  Close  Predictions
# Date
# 2021-04-21  744.119995   662.673340
# 2021-04-22  719.690002   666.498169
# 2021-04-23  729.400024   666.184753
# 2021-04-26  738.200012   667.086548
# 2021-04-27  704.739990   669.643066
# 2021-04-28  694.400024   665.961487
# 2021-04-29  677.000000   660.274719
# 2021-04-30  709.440002   652.609192
# 2021-05-03  684.900024   652.474731
# 2021-05-04  673.599976   649.468201
# 2021-05-05  670.940002   644.646912
# 2021-05-06  663.539978   640.133972
# 2021-05-07  672.369995   635.427185
# 2021-05-10  629.039978   633.414551
# 2021-05-11  617.200012   624.496399
# 2021-05-12  589.890015   614.239258
# 2021-05-13  571.690002   601.231995
# 2021-05-14  589.739990   587.566589
# 2021-05-17  576.830017   580.443115
# 2021-05-18  577.869995   573.947388
# 2021-05-19  554.299988   569.176208

# %%
# Create the training data set 
# Create the scaled training data set
train_data6 = scaled_data6[0:int(training_data_len6), :]
# Split the data into x_train and y_train data sets
x_train6 = []
y_train6 = []

for i in range(60, len(train_data6)):
    x_train6.append(train_data6[i-60:i, 0])
    y_train6.append(train_data6[i, 0])
    if i<= 61:
        print(x_train6)
        print(y_train6)
        print()
        
# Convert the x_train and y_train to numpy arrays 
x_train6, y_train6 = np.array(x_train6), np.array(y_train6)

# Reshape the data
x_train6 = np.reshape(x_train6, (x_train6.shape[0], x_train6.shape[1], 1))
# x_train.shape
# Out:
# [array([0.05830988, 0.0601085 , 0.061588  , 0.05123147, 0.0507383 ,
#        0.05082533, 0.05213078, 0.0521888 , 0.05134751, 0.05134751,
#        0.05224681, 0.05137652, 0.05111543, 0.04998405, 0.04969395,
#        0.04885266, 0.04972296, 0.04949088, 0.04922979, 0.04969395,
#        0.05056424, 0.05137652, 0.05018711, 0.05033216, 0.04899771,
#        0.04647385, 0.04748919, 0.04804038, 0.04748919, 0.04696701,
#        0.0478083 , 0.04821444, 0.04789533, 0.0472281 , 0.0466189 ,
#        0.04658989, 0.04267355, 0.04177425, 0.04261553, 0.04261553,
#        0.04365989, 0.04348583, 0.04432711, 0.0454585 , 0.04426909,
#        0.04490731, 0.04801137, 0.04760523, 0.04815642, 0.04818543,
#        0.04949088, 0.05326216, 0.05311711, 0.0545386 , 0.05627919,
#        0.0548577 , 0.05506078, 0.05569899, 0.05503177, 0.05517681])]
# [0.05543790244282607]
#
# [array([0.05830988, 0.0601085 , 0.061588  , 0.05123147, 0.0507383 ,
#        0.05082533, 0.05213078, 0.0521888 , 0.05134751, 0.05134751,
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# Build the LSTM model
model6 = Sequential()
model6.add(LSTM(128, return_sequences=True, input_shape= (x_train6.shape[1], 1)))
model6.add(LSTM(64, return_sequences=False))
model6.add(Dense(25))
model6.add(Dense(1))

# Compile the model
model6.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model6.fit(x_train6, y_train6, batch_size=1, epochs=2)
# Out:
# Epoch 1/2
# 2661/2661 [==============================] - 79s 29ms/step - loss: 9.2906e-05
# Epoch 2/2
# 2661/2661 [==============================] - 77s 29ms/step - loss: 2.3197e-05

# %%
# Create the testing data set
# Create a new array containing scaled values from index 1543 to 2002 
test_data6 = scaled_data6[training_data_len6 - 60: , :]
# Create the data sets x_test and y_test
x_test6 = []
y_test6 = dataset6[training_data_len6:, :]
for i in range(60, len(test_data6)):
    x_test6.append(test_data6[i-60:i, 0])
    
# Convert the data to a numpy array
x_test6 = np.array(x_test6)

# Reshape the data
x_test6 = np.reshape(x_test6, (x_test6.shape[0], x_test6.shape[1], 1 ))

# Get the models predicted price values 
predictions6 = model6.predict(x_test6)
predictions6 = scaler6.inverse_transform(predictions6)

# Get the root mean squared error (RMSE)
rmse6 = np.sqrt(np.mean(((predictions6 - y_test6) ** 2)))
rmse6
# Out:
# 31.623815929184808

# %%
# Plot the data
train6 = data6[:training_data_len6]
valid6 = data6[training_data_len6:]
valid6['Predictions'] = predictions6
# Visualize the data
plt.figure(figsize=(16,6))
plt.title('GameStock')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train6['Close'])
plt.plot(valid6[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
valid6
# Out:
#                  Close  Predictions
# Date
# 2020-10-23   15.000000    15.481840
# 2020-10-26   13.450000    15.841640
# 2020-10-27   12.690000    14.952311
# 2020-10-28   11.820000    13.915627
# 2020-10-29   11.730000    12.920908
# ...                ...          ...
# 2021-05-13  164.500000   154.053970
# 2021-05-14  159.919998   167.570511
# 2021-05-17  180.600006   171.803391
# 2021-05-18  180.669998   186.340240
# 2021-05-19  173.880005   192.723022
#
# [143 rows x 2 columns]

# %%
# Create the training data set 
# Create the scaled training data set
train_data7 = scaled_data7[0:int(training_data_len7), :]
# Split the data into x_train and y_train data sets
x_train7 = []
y_train7 = []

for i in range(60, len(train_data7)):
    x_train7.append(train_data7[i-60:i, 0])
    y_train7.append(train_data7[i, 0])
    if i<= 61:
        print(x_train7)
        print(y_train7)
        print()
        
# Convert the x_train and y_train to numpy arrays 
x_train7, y_train7 = np.array(x_train7), np.array(y_train7)

# Reshape the data
x_train7 = np.reshape(x_train7, (x_train7.shape[0], x_train7.shape[1], 1))
# x_train.shape
# Out:
# [array([0.29436591, 0.29056763, 0.29352183, 0.2846592 , 0.28107194,
#        0.28043892, 0.27220931, 0.28107194, 0.28381516, 0.27980586,
#        0.28107194, 0.27368641, 0.26376872, 0.25743829, 0.25997044,
#        0.25490609, 0.23633677, 0.23148343, 0.2226208 , 0.24414432,
#        0.24330026, 0.24604346, 0.21797847, 0.21523527, 0.21924457,
#        0.22641908, 0.22304282, 0.23253851, 0.23401561, 0.24182316,
#        0.24984174, 0.24435534, 0.23802489, 0.2422452 , 0.23359357,
#        0.23464865, 0.22726314, 0.25532813, 0.26630092, 0.2831821 ,
#        0.2861363 , 0.28909053, 0.30554968, 0.29373285, 0.30343952,
#        0.30618274, 0.2987972 , 0.29753112, 0.29710909, 0.3042836 ,
#        0.30998101, 0.29921924, 0.29373285, 0.29647603, 0.29373285,
#        0.28634732, 0.27980586, 0.28845747, 0.28803543, 0.30449462])]
# [0.30343951819384757]
#
# [array([0.29436591, 0.29056763, 0.29352183, 0.2846592 , 0.28107194,
#        0.28043892, 0.27220931, 0.28107194, 0.28381516, 0.27980586,
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# Build the LSTM model
model7 = Sequential()
model7.add(LSTM(128, return_sequences=True, input_shape= (x_train7.shape[1], 1)))
model7.add(LSTM(64, return_sequences=False))
model7.add(Dense(25))
model7.add(Dense(1))

# Compile the model
model7.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model7.fit(x_train7, y_train7, batch_size=1, epochs=2)
# Out:
# Epoch 1/2
# 2661/2661 [==============================] - 80s 29ms/step - loss: 0.0033
# Epoch 2/2
# 2661/2661 [==============================] - 76s 29ms/step - loss: 6.0893e-04

# %%
# Create the testing data set
# Create a new array containing scaled values from index 1543 to 2002 
test_data7 = scaled_data7[training_data_len7 - 60: , :]
# Create the data sets x_test and y_test
x_test7 = []
y_test7 = dataset7[training_data_len7:, :]
for i in range(60, len(test_data7)):
    x_test7.append(test_data7[i-60:i, 0])
    
# Convert the data to a numpy array
x_test7 = np.array(x_test7)

# Reshape the data
x_test7 = np.reshape(x_test7, (x_test7.shape[0], x_test7.shape[1], 1 ))

# Get the models predicted price values 
predictions7 = model7.predict(x_test7)
predictions7 = scaler7.inverse_transform(predictions7)

# Get the root mean squared error (RMSE)
rmse7 = np.sqrt(np.mean(((predictions7 - y_test7) ** 2)))
rmse7
# Out:
# 0.6490191011515111

# %%
# Plot the data
train7 = data7[:training_data_len7]
valid7 = data7[training_data_len7:]
valid7['Predictions'] = predictions7
# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Tata Motors')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train7['Close'])
plt.plot(valid7[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
valid7
# Out:
#             Close  Predictions
# Date
# 2020-10-23   9.32     9.214375
# 2020-10-26   9.06     9.410492
# 2020-10-27   9.48     9.322968
# 2020-10-28   8.85     9.515171
# 2020-10-29   8.93     9.225361
# ...           ...          ...
# 2021-05-13  21.66    21.358234
# 2021-05-14  21.24    21.547783
# 2021-05-17  21.90    21.299637
# 2021-05-18  21.91    21.674192
# 2021-05-19  20.77    21.830660
#
# [143 rows x 2 columns]

# %%
# Create the training data set 
# Create the scaled training data set
train_data8 = scaled_data8[0:int(training_data_len8), :]
# Split the data into x_train and y_train data sets
x_train8 = []
y_train8 = []

for i in range(60, len(train_data8)):
    x_train8.append(train_data8[i-60:i, 0])
    y_train8.append(train_data8[i, 0])
    if i<= 61:
        print(x_train8)
        print(y_train8)
        print()
        
# Convert the x_train and y_train to numpy arrays 
x_train8, y_train8 = np.array(x_train8), np.array(y_train8)

# Reshape the data
x_train8 = np.reshape(x_train8, (x_train8.shape[0], x_train8.shape[1], 1))
# x_train.shape
# Out:
# [array([0.09352615, 0.09104681, 0.10179062, 0.1       , 0.11280989,
#        0.10612947, 0.10013774, 0.10261706, 0.09566115, 0.08553717,
#        0.09207988, 0.10206611, 0.09269972, 0.07741045, 0.08078512,
#        0.07038565, 0.06831954, 0.0630854 , 0.05991736, 0.07017905,
#        0.07617078, 0.06997245, 0.05110191, 0.0626033 , 0.05523416,
#        0.06508265, 0.06108814, 0.07066114, 0.07417355, 0.08264463,
#        0.08601927, 0.08236914, 0.08250688, 0.08367767, 0.07417355,
#        0.07947659, 0.08491734, 0.08471074, 0.09276857, 0.09724517,
#        0.09634984, 0.09917353, 0.10461431, 0.10516529, 0.10303029,
#        0.10516529, 0.10550964, 0.10592284, 0.10461431, 0.1123278 ,
#        0.11308538, 0.10399448, 0.09586775, 0.10888428, 0.11852616,
#        0.11274104, 0.10564738, 0.11101927, 0.12685949, 0.11955923])]
# [0.11838841656177565]
#
# [array([0.09352615, 0.09104681, 0.10179062, 0.1       , 0.11280989,
#        0.10612947, 0.10013774, 0.10261706, 0.09566115, 0.08553717,
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# Build the LSTM model
model8 = Sequential()
model8.add(LSTM(128, return_sequences=True, input_shape= (x_train8.shape[1], 1)))
model8.add(LSTM(64, return_sequences=False))
model8.add(Dense(25))
model8.add(Dense(1))

# Compile the model
model8.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model8.fit(x_train8, y_train8, batch_size=1, epochs=2)
# Out:
# Epoch 1/2
# 2661/2661 [==============================] - 81s 29ms/step - loss: 0.0018
# Epoch 2/2
# 2661/2661 [==============================] - 78s 29ms/step - loss: 5.1380e-04

# %%
# Create the testing data set
# Create a new array containing scaled values from index 1543 to 2002 
test_data8 = scaled_data8[training_data_len8 - 60: , :]
# Create the data sets x_test and y_test
x_test8 = []
y_test8 = dataset8[training_data_len8:, :]
for i in range(60, len(test_data8)):
    x_test8.append(test_data8[i-60:i, 0])
    
# Convert the data to a numpy array
x_test8 = np.array(x_test8)

# Reshape the data
x_test8 = np.reshape(x_test8, (x_test8.shape[0], x_test8.shape[1], 1 ))

# Get the models predicted price values 
predictions8 = model8.predict(x_test8)
predictions8 = scaler8.inverse_transform(predictions8)

# Get the root mean squared error (RMSE)
rmse8 = np.sqrt(np.mean(((predictions8 - y_test8) ** 2)))
rmse8
# Out:
# 2.8968515274260525

# %%
# Plot the data
train8 = data8[:training_data_len8]
valid8 = data8[training_data_len8:]
valid8['Predictions'] = predictions8
# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Reliance Steel')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train8['Close'])
plt.plot(valid8[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
valid8
# Out:
#                  Close  Predictions
# Date
# 2020-10-23  111.239998   110.956528
# 2020-10-26  107.900002   110.998833
# 2020-10-27  108.889999   109.107933
# 2020-10-28  106.339996   108.886307
# 2020-10-29  108.709999   107.473312
# ...                ...          ...
# 2021-05-13  172.440002   168.366699
# 2021-05-14  170.559998   169.635910
# 2021-05-17  170.600006   169.627090
# 2021-05-18  167.809998   169.831726
# 2021-05-19  163.000000   168.182632
#
# [143 rows x 2 columns]
